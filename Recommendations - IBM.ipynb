# %%
import numpy as np  
import pandas as pd
import scipy.sparse as sparse

from scipy.sparse.linalg import spsolve
customer_list1 = pd.read_csv("E:\\Business analytics with R\\train.csv") 
customer_list = pd.read_csv("E:\\Business analytics with R\\test.csv")
customer_list1.head(2)
# Out:
#    CustomerID  InvoiceNo  Quantity     InvoiceDate  UnitPrice Country  \
# 0       27270      27270         7  1/12/2010 8:26       2.55      PX
# 1       27270      27270         7  1/12/2010 8:26       3.39      PX
#
#   StockCode
# 0   85123AY
# 1    71053R

# %%
customer_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330575 entries, 0 to 330574
# Data columns (total 7 columns):
# CustomerID     330575 non-null int64
# InvoiceNo      330575 non-null int64
# Quantity       330575 non-null int64
# InvoiceDate    330575 non-null object
# UnitPrice      330575 non-null float64
# Country        330575 non-null object
# StockCode      330575 non-null object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 17.7+ MB

# %%
customer_list.head(2)
# Out:
#   Country  CustomerID    InvoiceDate  InvoiceNo  Quantity StockCode  UnitPrice
# 0      PX      127269  01/12/10 8:28     127269         7    22633V       1.85
# 1      PX      227268  01/12/10 8:34     227268        38    84879M       1.69

# %%
item_lookup = customer_list[['StockCode', 'UnitPrice']].drop_duplicates() # unique item/UnitPrice pairs
item_lookup['StockCode'] = item_lookup.StockCode.astype(str) # Encode as strings

# %%
item_lookup.head()
# Out:
#   StockCode  UnitPrice
# 0    22633V       1.85
# 1    84879M       1.69
# 2    22748P       2.10
# 3    22749K       3.75
# 4    22622G       9.95

# %%
customer_list['CustomerID'] = customer_list.CustomerID.astype(int)
customer_list = customer_list[['StockCode', 'Quantity', 'CustomerID']]
grouped_customerlist = customer_list.groupby(['CustomerID', 'StockCode']).sum().reset_index() 
grouped_customerlist.Quantity.loc[grouped_customerlist.Quantity == 0] = 1 # indicate purchased
grouped_purchased = grouped_customerlist.query('Quantity > 0') # show customers whose purchase totals were positive
# Out:
# C:\ProgramData\New folder\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
grouped_purchased.head()
# Out:
#    CustomerID StockCode  Quantity
# 0        1890    21080R         4
# 1        1890    21094A        13
# 2        1890    21770E         2
# 3        1890    22366J         2
# 4        1890    22413V         7

# %%
customers = list(np.sort(customer_list.CustomerID.unique()))
products = list(customer_list.StockCode.unique())
quantity = list(customer_list.Quantity)

rows = customer_list.CustomerID.astype('category', categories = customers).cat.codes 
cols = customer_list.StockCode.astype('category', categories = products).cat.codes 
purchases_sparse = sparse.csr_matrix((quantity, (rows, cols)), shape=(len(customers), len(products)))
# Out:
# C:\ProgramData\New folder\lib\site-packages\IPython\core\interactiveshell.py:3296: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
purchases_sparse
# Out:
# <628x3522 sparse matrix of type '<class 'numpy.int32'>'
# 	with 85260 stored elements in Compressed Sparse Row format>

# %%
matrix_size = purchases_sparse.shape[0]*purchases_sparse.shape[1] # possible interactions
num_purchases = len(purchases_sparse.nonzero()[0]) #  no items interacted 
sparsity = 100*(1 - (num_purchases/matrix_size))
sparsity
# Out:
# 96.14787125149651

# %%
import random

# %%
def make_train(ratings, pct_test = 0.2):
    test_set = ratings.copy() 
    test_set[test_set != 0] = 1 # binary preference matrix
    training_set = ratings.copy() 
    nonzero_inds = training_set.nonzero() # interaction exists
    nonzero_pairs = list(zip(nonzero_inds[0], nonzero_inds[1])) # convert user,item index into list
    random.seed(0) 
    num_samples = int(np.ceil(pct_test*len(nonzero_pairs))) #roundoff
    samples = random.sample(nonzero_pairs, num_samples) # random number of user-item pairs without replacement
    user_inds = [index[0] for index in samples] # user row indices
    item_inds = [index[1] for index in samples] # item column indices
    training_set[user_inds, item_inds] = 0 #randomly chosen user-item pairs to zero
    training_set.eliminate_zeros() # Get rid of zeros in sparse array
    return training_set, test_set, list(set(user_inds)) # unique list of user rows

# %%
product_train, product_test, product_users_altered = make_train(purchases_sparse, pct_test = 0.2)

# %%
def implicit_weighted_ALS(training_set, lambda_val = 0.1, alpha = 40, iterations = 10, rank_size = 20, seed = 0):
    conf = (alpha*training_set) 
    num_user = conf.shape[0]
    num_item = conf.shape[1] 
    rstate = np.random.RandomState(seed)
    X = sparse.csr_matrix(rstate.normal(size = (num_user, rank_size))) # users in a m x rank shape
    Y = sparse.csr_matrix(rstate.normal(size = (num_item, rank_size))) 
    X_eye = sparse.eye(num_user) 
    Y_eye = sparse.eye(num_item)
    lambda_eye = lambda_val * sparse.eye(rank_size) 
    for iter_step in range(iterations): #iterations
        #tuning
        yTy = Y.T.dot(Y)
        xTx = X.T.dot(X)
        #fixed y
        for u in range(num_user):
            conf_samp = conf[u,:].toarray() 
            pref = conf_samp.copy() 
            pref[pref != 0] = 1 # binarized preference vector 
            CuI = sparse.diags(conf_samp, [0])  #Ci - I term
            yTCuIY = Y.T.dot(CuI).dot(Y) # yT(Cu-I)Y term 
            yTCupu = Y.T.dot(CuI + Y_eye).dot(pref.T) #yTCuPu term
            X[u] = spsolve(yTy + yTCuIY + lambda_eye, yTCupu) #minimization
        #fixed X 
        for i in range(num_item):
            conf_samp = conf[:,i].T.toarray() #  row format
            pref = conf_samp.copy()
            pref[pref != 0] = 1 
            CiI = sparse.diags(conf_samp, [0]) 
            xTCiIX = X.T.dot(CiI).dot(X) 
            xTCiPi = X.T.dot(CiI + X_eye).dot(pref.T) 
            Y[i] = spsolve(xTx + xTCiIX + lambda_eye, xTCiPi)
        return X, Y.T

# %%
user_vecs, item_vecs = implicit_weighted_ALS(product_train, lambda_val = 0.1, alpha = 15, iterations = 1,
                                            rank_size = 20)

# %%
user_vecs[0,:].dot(item_vecs).toarray()[0,:5]
# Out:
# array([-0.05326089,  0.06395472, -0.01473672, -0.01574714,  0.06518385])

# %%
import implicit

# %%
alpha = 15
user_vecs, item_vecs = implicit.alternating_least_squares((product_train*alpha).astype('double'), 
                                                          factors=20, 
                                                           regularization = 0.1, 
                                                         iterations = 50)
# Out:
# WARNING:implicit:This method is deprecated. Please use the AlternatingLeastSquares class instead
# 100%|████████████████████████████████████████████████████████████████████████████████| 50.0/50 [00:00<00:00, 78.69it/s]

# %%
from sklearn import metrics

# %%
def auc_score(predictions, test):
    fpr, tpr, thresholds = metrics.roc_curve(test, predictions)
    return metrics.auc(fpr, tpr)

# %%
def calc_mean_auc(training_set, altered_users, predictions, test_set):
    store_auc = [] 
    popularity_auc = [] 
    pop_items = np.array(test_set.sum(axis = 0)).reshape(-1) # Get sum of item iteractions to find most popular
    item_vecs = predictions[1]
    for user in altered_users: 
        training_row = training_set[user,:].toarray().reshape(-1) 
        zero_inds = np.where(training_row == 0) #check for interactions
        # predicted values based on our user/item vectors
        user_vec = predictions[0][user,:]
        pred = user_vec.dot(item_vecs).toarray()[0,zero_inds].reshape(-1)
        # items that were originally zero
        # Selecting for this user that originally had no iteraction
        actual = test_set[user,:].toarray()[0,zero_inds].reshape(-1) 
        # Select the binarized yes/no interaction pairs from the original full data
        # that align with the same pairs in training 
        pop = pop_items[zero_inds] #  popularity for our chosen items
        store_auc.append(auc_score(pred, actual)) 
        popularity_auc.append(auc_score(pop, actual))

    return float('%.3f'%np.mean(store_auc)), float('%.3f'%np.mean(popularity_auc))

# %%
calc_mean_auc(product_train, product_users_altered, 
              [sparse.csr_matrix(user_vecs), sparse.csr_matrix(item_vecs.T)], product_test)
# Out:
# (0.72, 0.803)

# %%
customers_arr = np.array(customers) 
products_arr = np.array(products)

# %%
def get_items_purchased(customer_id, mf_train, customers_list, products_list, item_lookup):
    cust_ind = np.where(customers_list == customer_id)[0][0] #index row of cust id
    purchased_ind = mf_train[cust_ind,:].nonzero()[1] # index of purchased items
    prod_codes = products_list[purchased_ind] #stock codes for our purchased items
    return item_lookup.loc[item_lookup.StockCode.isin(prod_codes)]

# %%
customers_arr[:5]
# Out:
# array([1890, 2700, 3600, 3690, 4500], dtype=int64)

# %%
get_items_purchased(3600, product_train, customers_arr, products_arr, item_lookup).head()
# Out:
#    StockCode  UnitPrice
# 0     22633V       1.85
# 19    22726C       3.75
# 51    22114V       3.95
# 57    48185J       7.95
# 63    22111I       4.95

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
def recommend_items(customer_id, mf_train, user_vecs, item_vecs, customer_list, item_list, item_lookup, num_items = 10):
    cust_ind = np.where(customer_list == customer_id)[0][0] # Returns the index row of our customer id
    pref_vec = mf_train[cust_ind,:].toarray() #rating from train set
    pref_vec = pref_vec.reshape(-1) + 1 #to make every item positive
    rec_vector = user_vecs[cust_ind,:].dot(item_vecs.T) #dot product
    min_max = MinMaxScaler()
    rec_vector_scaled = min_max.fit_transform(rec_vector.reshape(-1,1))[:,0]  
    recommend_vector = pref_vec*rec_vector_scaled #scaling
    product_idx = np.argsort(recommend_vector)[::-1][:num_items] #sorting in best of rec
    rec_list = [] 
    for index in product_idx:
        code = item_list[index]
        rec_list.append([code, item_lookup.UnitPrice.loc[item_lookup.StockCode == code].iloc[0]]) 
        rec_list.append([code, item_lookup.UnitPrice.loc[item_lookup.StockCode == code].iloc[0]]) 
    codes = [item[0] for item in rec_list]
    UnitPrice1 = [item[1] for item in rec_list]
    final_frame = pd.DataFrame({'StockCode': codes, 'UnitPrice': UnitPrice1}) 
    return final_frame[['StockCode', 'UnitPrice']]

# %%
recommend_items(129069
, product_train, user_vecs, item_vecs, customers_arr, products_arr, item_lookup,
                       num_items = 30)
# Out:
#    StockCode  UnitPrice
# 0     22355U       1.66
# 1     21746N       2.51
# 2     22086O       5.91
# 3     84077K       0.29
# 4     20724F       1.66
# 5     84945I       0.85
# 6     22791E       1.25
# 7     23232F       0.42
# 8     84347V       2.55
# 9     21967J       0.29
# 10    22906G       1.65
# 11    22616B       0.29
# 12    21718N       2.51
# 13    21980L       0.29
# 14   47593BL       0.85
# 15    84879M       1.69
# 16    84946F       2.51
# 17    23084M       2.08
# 18    21479J       3.75
# 19    22630B       1.95
# 20    22629C       1.95
# 21    22555O       1.65
# 22    22711H       0.42
# 23    23230A       0.42
# 24    22457C       2.95
# 25    23238P       4.15
# 26    21390P       1.25
# 27    21715T       2.55
# 28    23076Z       2.46
# 29    23493H       1.95

# %%
#def predict(customer_list):
Customers = list(np.sort(customer_list.CustomerID.unique()))
final_frame1 = pd.DataFrame({'Customer': Customers})
for c in final_frame1.loc[:,'Customer']:
    print (recommend_items(c,product_train, user_vecs, item_vecs, customers_arr, products_arr, item_lookup,
                       num_items = 1),c)
# Out:
#   StockCode  UnitPrice
# 0    22851J       1.66 1890
#   StockCode  UnitPrice
# 0    23205F       0.85 2700
#   StockCode  UnitPrice
# 0    48194E      14.43 3600
#   StockCode  UnitPrice
# 0   85099BJ       1.65 3690
#   StockCode  UnitPrice
# 0    22536B       0.85 4500
#   StockCode  UnitPrice
# 0    22188M       3.95 5490
#   StockCode  UnitPrice
# 0    21733F       2.95 8190
#   StockCode  UnitPrice
# 0    23300F       1.65 9090
#   StockCode  UnitPrice
# 0    20972O       1.25 13680
#   StockCode  UnitPrice
# 0    21135E       1.69 14490
#   StockCode  UnitPrice
# 0    23307D       0.55 14580
#   StockCode  UnitPrice
# 0    23208E       1.65 15390
#   StockCode  UnitPrice
# 0    21122K       1.06 18090
#   StockCode  UnitPrice
# 0    22151L       0.42 18180
#   StockCode  UnitPrice
# 0    22693N       1.25 19980
#   StockCode  UnitPrice
# 0    21175V        2.1 22770
#   StockCode  UnitPrice
# 0    22492E       1.66 23580
#   StockCode  UnitPrice
# 0    16259V       0.21 24480
#   StockCode  UnitPrice
# 0    22178V       2.51 24570
#   StockCode  UnitPrice
# 0    22727B       3.75 25569
#   StockCode  UnitPrice
# 0   85099BJ       1.65 26370
#   StockCode  UnitPrice
# 0    22178V       2.51 28080
#   StockCode  UnitPrice
# 0    21918L       0.42 28170
#   StockCode  UnitPrice
# 0    35970L       4.13 28179
#   StockCode  UnitPrice
# 0    22910D       5.91 28269
#   StockCode  UnitPrice
# 0    22339G       1.28 29169
#   StockCode  UnitPrice
# 0    71459J       0.85 29970
#   StockCode  UnitPrice
# 0    20668K        0.1 30969
#   StockCode  UnitPrice
# 0    20914Q       2.55 31770
#   StockCode  UnitPrice
# 0    23351C       1.25 31869
#   StockCode  UnitPrice
# 0    23552T       2.08 31959
#   StockCode  UnitPrice
# 0    23310X       0.42 33660
#   StockCode  UnitPrice
# 0    22998M       0.42 34470
#   StockCode  UnitPrice
# 0    22161W       0.81 34569
#   StockCode  UnitPrice
# 0   85099CQ       1.95 36360
#   StockCode  UnitPrice
# 0   85099BJ       1.65 36459
#   StockCode  UnitPrice
# 0    22555O       1.65 37269
#   StockCode  UnitPrice
# 0    17003M       0.42 38160
#   StockCode  UnitPrice
# 0    82482D        2.1 39159
#   StockCode  UnitPrice
# 0    84077K       0.29 40059
#   StockCode  UnitPrice
# 0    84879M       1.69 41760
#   StockCode  UnitPrice
# 0    22866X        2.1 41859
#   StockCode  UnitPrice
# 0    21811V       2.51 42750
#   StockCode  UnitPrice
# 0    21231K       2.51 42849
#   StockCode  UnitPrice
# 0    21731V       3.36 43659
#   StockCode  UnitPrice
# 0    22740K       1.66 44460
#   StockCode  UnitPrice
# 0    21479J       3.75 44559
#   StockCode  UnitPrice
# 0    22149E       4.21 44649
#   StockCode  UnitPrice
# 0    21213V       0.55 46350
#   StockCode  UnitPrice
# 0    22152O       0.42 47160
#   StockCode  UnitPrice
# 0    21891R       1.25 48150
#   StockCode  UnitPrice
# 0    23161A       1.25 48159
#   StockCode  UnitPrice
# 0    23307D       0.55 51939
#   StockCode  UnitPrice
# 0    23249Y       1.65 52839
#   StockCode  UnitPrice
# 0    21166I       1.95 53649
#   StockCode  UnitPrice
# 0    21195Z       4.21 53739
#   StockCode  UnitPrice
# 0    23076Z       2.46 54549
#   StockCode  UnitPrice
# 0    17003M       0.42 54639
#   StockCode  UnitPrice
# 0    22178V       2.51 55440
#   StockCode  UnitPrice
# 0    22993E       1.06 56349
#   StockCode  UnitPrice
# 0    20984B       0.85 56439
#   StockCode  UnitPrice
# 0    22492E       1.66 57240
#   StockCode  UnitPrice
# 0    21656H       3.36 58050
#   StockCode  UnitPrice
# 0   16169EL       0.42 58140
#   StockCode  UnitPrice
# 0    10002F       1.66 58239
#   StockCode  UnitPrice
# 0    20711L       1.65 59139
#   StockCode  UnitPrice
# 0    21123F       1.25 59940
#   StockCode  UnitPrice
# 0    23301G       1.65 60840
#   StockCode  UnitPrice
# 0    21094A       0.64 61839
#   StockCode  UnitPrice
# 0    22154A       0.42 62730
#   StockCode  UnitPrice
# 0    22578A       0.85 63630
#   StockCode  UnitPrice
# 0   82494LP       2.95 63729
#   StockCode  UnitPrice
# 0    22999A       0.42 65430
#   StockCode  UnitPrice
# 0    22419N       0.85 66339
#   StockCode  UnitPrice
# 0    22197J       0.85 66429
#   StockCode  UnitPrice
# 0    22578A       0.85 67140
#   StockCode  UnitPrice
# 0    23084M       2.08 67230
#   StockCode  UnitPrice
# 0    22178V       2.51 67239
#   StockCode  UnitPrice
# 0    23171H       1.65 67329
#   StockCode  UnitPrice
# 0   16156SH       0.42 68040
#   StockCode  UnitPrice
# 0    22144E        2.1 68130
#   StockCode  UnitPrice
# 0    22086O       5.91 69030
#   StockCode  UnitPrice
# 0    22151L       0.42 70029
#   StockCode  UnitPrice
# 0    22189I       3.95 70929
#   StockCode  UnitPrice
# 0    22338I       0.65 71919
#   StockCode  UnitPrice
# 0    84946F       2.51 72630
#   StockCode  UnitPrice
# 0    22560W       1.25 74430
#   StockCode  UnitPrice
# 0    22338I       0.65 75420
#   StockCode  UnitPrice
# 0    22151L       0.42 75519
#   StockCode  UnitPrice
# 0    21879Z       0.19 76320
#   StockCode  UnitPrice
# 0    21891R       1.25 76419
#   StockCode  UnitPrice
# 0    16259V       0.21 77229
#   StockCode  UnitPrice
# 0    23843K       2.08 78030
#   StockCode  UnitPrice
# 0    22622G       9.95 78120
#   StockCode  UnitPrice
# 0    84568Z       0.21 78219
#   StockCode  UnitPrice
# 0    22075W       1.65 79020
#   StockCode  UnitPrice
# 0    23186V       1.25 81909
#   StockCode  UnitPrice
# 0    23297N       1.65 83619
#   StockCode  UnitPrice
# 0    21212D       0.55 83709
#   StockCode  UnitPrice
# 0    22616B       0.29 84519
#   StockCode  UnitPrice
# 0    22910D       5.91 84609
#   StockCode  UnitPrice
# 0    84598D       0.43 86409
#   StockCode  UnitPrice
# 0    22923F       0.85 88209
#   StockCode  UnitPrice
# 0    22609U       1.66 91899
#   StockCode  UnitPrice
# 0    22326L       5.91 93609
#   StockCode  UnitPrice
# 0    62018W       1.25 94509
#   StockCode  UnitPrice
# 0    22969Z       1.45 95409
#   StockCode  UnitPrice
# 0    22578A       0.85 96399
#   StockCode  UnitPrice
# 0    20668K        0.1 97299
#   StockCode  UnitPrice
# 0    20724F       1.66 99999
#   StockCode  UnitPrice
# 0    21703M       0.42 100899
#   StockCode  UnitPrice
# 0    84978X       1.25 104589
#   StockCode  UnitPrice
# 0    20719E       0.85 105489
#   StockCode  UnitPrice
# 0    22752G       7.65 108099
#   StockCode  UnitPrice
# 0    22197J       0.85 108189
#   StockCode  UnitPrice
# 0    22151L       0.42 109989
#   StockCode  UnitPrice
# 0    23201S       2.08 112689
#   StockCode  UnitPrice
# 0   84970LF       0.95 112779
#   StockCode  UnitPrice
# 0    20727V       1.65 113679
#   StockCode  UnitPrice
# 0    21399R       0.39 115389
#   StockCode  UnitPrice
# 0    22616B       0.29 116289
#   StockCode  UnitPrice
# 0    21232B       1.25 117189
#   StockCode  UnitPrice
# 0    21108Z       5.06 117279
#   StockCode  UnitPrice
# 0    84879M       1.69 118179
#   StockCode  UnitPrice
# 0    20668K        0.1 119979
#   StockCode  UnitPrice
# 0   84997DC       3.75 121869
#   StockCode  UnitPrice
# 0    85175B       0.42 122679
#   StockCode  UnitPrice
# 0    22595D       0.85 122778
#   StockCode  UnitPrice
# 0    84568Z       0.21 124479
#   StockCode  UnitPrice
# 0    23282K       0.83 126468
#   StockCode  UnitPrice
# 0    48138T       7.95 127269
#   StockCode  UnitPrice
# 0    21803X       0.43 128079
#   StockCode  UnitPrice
# 0    22355U       1.66 129069
#   StockCode  UnitPrice
# 0    21929W       4.21 130869
#   StockCode  UnitPrice
# 0    21212D       0.55 131769
#   StockCode  UnitPrice
# 0    21981M       0.81 131958
#   StockCode  UnitPrice
# 0   84997CQ       3.75 132759
#   StockCode  UnitPrice
# 0    21642S       1.66 132858
#   StockCode  UnitPrice
# 0    21137F       7.62 133569
#   StockCode  UnitPrice
# 0    22097D       1.25 133659
#   StockCode  UnitPrice
# 0    21988M       0.85 133668
#   StockCode  UnitPrice
# 0    84946F       2.51 133758
#   StockCode  UnitPrice
# 0    22178V       2.51 134469
#   StockCode  UnitPrice
# 0    22155O       0.85 134658
#   StockCode  UnitPrice
# 0    22741O       1.66 135468
#   StockCode  UnitPrice
# 0    84945I       0.85 135558
#   StockCode  UnitPrice
# 0    22294U       1.25 138168
#   StockCode  UnitPrice
# 0   85099BJ       1.65 139059
#   StockCode  UnitPrice
# 0   84535BP       0.65 139158
#   StockCode  UnitPrice
# 0    21380E       2.95 140058
#   StockCode  UnitPrice
# 0    22616B       0.29 140859
#   StockCode  UnitPrice
# 0    84945I       0.85 141849
#   StockCode  UnitPrice
# 0    84978X       1.25 142749
#   StockCode  UnitPrice
# 0    23581R       2.08 143649
#   StockCode  UnitPrice
# 0    22834J        2.1 143658
#   StockCode  UnitPrice
# 0    21154F       2.51 143748
#   StockCode  UnitPrice
# 0    84755J       1.27 144549
#   StockCode  UnitPrice
# 0    23355Z       4.15 145359
#   StockCode  UnitPrice
# 0   16161PA       0.42 145449
#   StockCode  UnitPrice
# 0    21977R       0.42 145458
#   StockCode  UnitPrice
# 0    22386V       1.95 146349
#   StockCode  UnitPrice
# 0    22178V       2.51 146358
#   StockCode  UnitPrice
# 0    22616B       0.29 146448
#   StockCode  UnitPrice
# 0    22197J       0.85 147258
#   StockCode  UnitPrice
# 0    22616B       0.29 148059
#   StockCode  UnitPrice
# 0    37413U       0.39 148149
#   StockCode  UnitPrice
# 0    22102P       1.65 149049
#   StockCode  UnitPrice
# 0    22197J       0.85 150948
#   StockCode  UnitPrice
# 0    22178V       2.51 151749
#   StockCode  UnitPrice
# 0    84568Z       0.21 151848
#   StockCode  UnitPrice
# 0   85049EP       1.25 152739
#   StockCode  UnitPrice
# 0    15036Z       0.75 152748
#   StockCode  UnitPrice
# 0   90058BX       0.38 152838
#   StockCode  UnitPrice
# 0    22952P       0.55 153549
#   StockCode  UnitPrice
# 0    22178V       2.51 153648
#   StockCode  UnitPrice
# 0    84755J       1.27 154638
#   StockCode  UnitPrice
# 0    23203B        0.0 155538
#   StockCode  UnitPrice
# 0    15034D       0.85 156249
#   StockCode  UnitPrice
# 0    23321O       1.69 156339
#   StockCode  UnitPrice
# 0    21786G       0.32 156438
#   StockCode  UnitPrice
# 0    22816Q       0.42 157248
#   StockCode  UnitPrice
# 0    22535E       0.85 157338
#   StockCode  UnitPrice
# 0    84879M       1.69 158238
#   StockCode  UnitPrice
# 0    21068Y       1.06 159939
#   StockCode  UnitPrice
# 0    17003M       0.42 160038
#   StockCode  UnitPrice
# 0    84992D       0.55 161739
#   StockCode  UnitPrice
# 0    21829T       0.43 161838
#   StockCode  UnitPrice
# 0    22492E       1.66 162738
#   StockCode  UnitPrice
# 0   85099BJ       1.65 162828
#   StockCode  UnitPrice
# 0    23321O       1.69 163629
#   StockCode  UnitPrice
# 0    85104W       2.95 163638
#   StockCode  UnitPrice
# 0    23076Z       2.46 164439
#   StockCode  UnitPrice
# 0    23489X       2.89 164529
#   StockCode  UnitPrice
# 0    84929V       0.55 164628
#   StockCode  UnitPrice
# 0    22338I       0.65 165438
#   StockCode  UnitPrice
# 0    22597M       1.66 166239
#   StockCode  UnitPrice
# 0   90209CQ       2.11 167328
#   StockCode  UnitPrice
# 0    22992G       1.95 168039
#   StockCode  UnitPrice
# 0    22572W       0.85 171729
#   StockCode  UnitPrice
# 0    23148U       0.83 171819
#   StockCode  UnitPrice
# 0    84568Z       0.21 171828
#   StockCode  UnitPrice
# 0    23583L       1.65 172629
#   StockCode  UnitPrice
# 0    84347V       2.55 173718
#   StockCode  UnitPrice
# 0    21212D       0.55 174618
#   StockCode  UnitPrice
# 0    22710N       0.42 175419
#   StockCode  UnitPrice
# 0    84879M       1.69 177219
#   StockCode  UnitPrice
# 0    23309L       0.55 178128
#   StockCode  UnitPrice
# 0    21523L       6.75 180819
#   StockCode  UnitPrice
# 0    23509S       0.42 180918
#   StockCode  UnitPrice
# 0   75049LA       2.46 182718
#   StockCode  UnitPrice
# 0    84879M       1.69 183618
#   StockCode  UnitPrice
# 0   85123AY       2.55 184608
#   StockCode  UnitPrice
# 0    23232F       0.42 185418
#   StockCode  UnitPrice
# 0    84879M       1.69 185508
#   StockCode  UnitPrice
# 0    84077K       0.29 187308
#   StockCode  UnitPrice
# 0    23583L       1.65 188118
#   StockCode  UnitPrice
# 0    22666I       2.95 189108
#   StockCode  UnitPrice
# 0    23493H       1.95 193608
#   StockCode  UnitPrice
# 0    21977R       0.42 193698
#   StockCode  UnitPrice
# 0    22616B       0.29 194598
#   StockCode  UnitPrice
# 0    22065D       1.45 195498
#   StockCode  UnitPrice
# 0    21495P       0.42 196308
#   StockCode  UnitPrice
# 0   18097CF       2.55 196398
#   StockCode  UnitPrice
# 0    21830E       0.85 197208
#   StockCode  UnitPrice
# 0    22993E       1.06 202788
#   StockCode  UnitPrice
# 0    20725N       1.65 203598
#   StockCode  UnitPrice
# 0    71459J       0.85 203688
#   StockCode  UnitPrice
# 0    22355U       1.66 204498
#   StockCode  UnitPrice
# 0    20725N       1.65 204588
#   StockCode  UnitPrice
# 0    22178V       2.51 205398
#   StockCode  UnitPrice
# 0    22792D       1.66 207288
#   StockCode  UnitPrice
# 0    22476N       4.95 209088
#   StockCode  UnitPrice
# 0    84077K       0.29 211878
#   StockCode  UnitPrice
# 0    22616B       0.29 214488
#   StockCode  UnitPrice
# 0    22610S       0.21 215478
#   StockCode  UnitPrice
# 0    21244H       1.69 217278
#   StockCode  UnitPrice
# 0    82484O       6.45 219078
#   StockCode  UnitPrice
# 0    21754X      11.87 220977
#   StockCode  UnitPrice
# 0    23084M       2.08 221778
#   StockCode  UnitPrice
# 0   75049LA       2.46 222678
#   StockCode  UnitPrice
# 0    20975Y       1.28 222777
#   StockCode  UnitPrice
# 0    23228Z       1.25 224667
#   StockCode  UnitPrice
# 0    22630B       1.95 225477
#   StockCode  UnitPrice
# 0    17003M       0.42 226278
#   StockCode  UnitPrice
# 0    20986H       1.25 226368
#   StockCode  UnitPrice
# 0    20668K        0.1 227268
#   StockCode  UnitPrice
# 0    22652D       1.65 227367
#   StockCode  UnitPrice
# 0    21731V       3.36 228267
#   StockCode  UnitPrice
# 0    84077K       0.29 229167
#   StockCode  UnitPrice
# 0    22151L       0.42 229968
#   StockCode  UnitPrice
# 0    35954V       0.42 231957
#   StockCode  UnitPrice
# 0    21069U       1.25 232668
#   StockCode  UnitPrice
# 0    70007C       1.65 232767
#   StockCode  UnitPrice
# 0    23084M       2.08 233568
#   StockCode  UnitPrice
# 0    20996R       0.42 233658
#   StockCode  UnitPrice
# 0    23083I       3.75 233757
#   StockCode  UnitPrice
# 0    22704P       0.42 234468
#   StockCode  UnitPrice
# 0   85185BY       2.95 235368
#   StockCode  UnitPrice
# 0    22491V       0.85 236358
#   StockCode  UnitPrice
# 0    23250A       1.25 236367
#   StockCode  UnitPrice
# 0    21213V       0.55 236457
#   StockCode  UnitPrice
# 0    22951B       0.55 237168
#   StockCode  UnitPrice
# 0    22489J       0.42 238068
#   StockCode  UnitPrice
# 0    21181K        2.1 238257
#   StockCode  UnitPrice
# 0    21918L       0.42 240957
#   StockCode  UnitPrice
# 0    21929W       4.21 241848
#   StockCode  UnitPrice
# 0    22952P       0.55 241857
#   StockCode  UnitPrice
# 0    22608F       0.21 242748
#   StockCode  UnitPrice
# 0    84946F       2.51 242847
#   StockCode  UnitPrice
# 0   84596BQ       0.85 243648
#   StockCode  UnitPrice
# 0    21500P       0.42 243747
#   StockCode  UnitPrice
# 0    22740K       1.66 244458
#   StockCode  UnitPrice
# 0    84947R       1.06 245448
#   StockCode  UnitPrice
# 0    22217R       1.25 245457
#   StockCode  UnitPrice
# 0    22338I       0.65 246447
#   StockCode  UnitPrice
# 0    21090G       0.83 248058
#   StockCode  UnitPrice
# 0    17038G        0.1 248148
#   StockCode  UnitPrice
# 0    15034D       0.85 249147
#   StockCode  UnitPrice
# 0    84832I       1.66 250848
#   StockCode  UnitPrice
# 0    22944W       1.25 251937
#   StockCode  UnitPrice
# 0    21900A       0.65 252738
#   StockCode  UnitPrice
# 0   85099BJ       1.65 252747
#   StockCode  UnitPrice
# 0    84077K       0.29 253638
#   StockCode  UnitPrice
# 0    22531M       0.85 255537
#   StockCode  UnitPrice
# 0    22197J       0.85 257247
#   StockCode  UnitPrice
# 0    21915K       1.25 257337
#   StockCode  UnitPrice
# 0    22208X       3.36 258048
#   StockCode  UnitPrice
# 0    16218Y       2.13 258138
#   StockCode  UnitPrice
# 0    22740K       1.66 259137
#   StockCode  UnitPrice
# 0    22299Q       1.25 259938
#   StockCode  UnitPrice
# 0    21287D       1.25 260838
#   StockCode  UnitPrice
# 0    22128V       1.25 261927
#   StockCode  UnitPrice
# 0    84879M       1.69 262827
#   StockCode  UnitPrice
# 0    84947R       1.06 263637
#   StockCode  UnitPrice
# 0    71053R       3.39 263727
#   StockCode  UnitPrice
# 0    23233W       0.42 264438
#   StockCode  UnitPrice
# 0   85199LV       1.28 264528
#   StockCode  UnitPrice
# 0   85099BJ       1.65 265527
#   StockCode  UnitPrice
# 0    21137F       7.62 267228
#   StockCode  UnitPrice
# 0    23171H       1.65 267327
#   StockCode  UnitPrice
# 0    79321V      10.17 268038
#   StockCode  UnitPrice
# 0    22178V       2.51 269127
#   StockCode  UnitPrice
# 0    22994B       0.83 269928
#   StockCode  UnitPrice
# 0   47590BU      11.02 271728
#   StockCode  UnitPrice
# 0    22571W       0.85 271818
#   StockCode  UnitPrice
# 0    62018W       1.25 271827
#   StockCode  UnitPrice
# 0    23084M       2.08 272628
#   StockCode  UnitPrice
# 0    23032G       1.65 272727
#   StockCode  UnitPrice
# 0   85123AY       2.55 272817
#   StockCode  UnitPrice
# 0    21988M       0.85 273618
#   StockCode  UnitPrice
# 0    22197J       0.85 275427
#   StockCode  UnitPrice
# 0    84946F       2.51 276228
#   StockCode  UnitPrice
# 0    22791E       1.25 276327
#   StockCode  UnitPrice
# 0    23084M       2.08 276417
#   StockCode  UnitPrice
# 0    23334M       0.63 277128
#   StockCode  UnitPrice
# 0    20975Y       1.28 277218
#   StockCode  UnitPrice
# 0    22998M       0.42 278217
#   StockCode  UnitPrice
# 0    21790Y       0.85 280818
#   StockCode  UnitPrice
# 0    21212D       0.55 281907
#   StockCode  UnitPrice
# 0    21787C       1.66 284607
#   StockCode  UnitPrice
# 0    17003M       0.42 285417
#   StockCode  UnitPrice
# 0    21891R       1.25 285507
#   StockCode  UnitPrice
# 0    85212R       1.66 291897
#   StockCode  UnitPrice
# 0    22066A       1.45 293697
#   StockCode  UnitPrice
# 0    20713F       1.95 294507
#   StockCode  UnitPrice
# 0    22951B       0.55 294597
#   StockCode  UnitPrice
# 0    23340L       1.65 295497
#   StockCode  UnitPrice
# 0   85099FC       1.95 298197
#   StockCode  UnitPrice
# 0    22386V       1.95 301797
#   StockCode  UnitPrice
# 0    16225Z       3.36 301887
#   StockCode  UnitPrice
# 0    22355U       1.66 302787
#   StockCode  UnitPrice
# 0    21035O       2.95 303597
#   StockCode  UnitPrice
# 0    22558H       1.49 303687
#   StockCode  UnitPrice
# 0    22114V       3.95 304587
#   StockCode  UnitPrice
# 0    23525T       2.66 305397
#   StockCode  UnitPrice
# 0    84568Z       0.21 305487
#   StockCode  UnitPrice
# 0    21985C       0.29 306297
#   StockCode  UnitPrice
# 0    22961C       1.45 306387
#   StockCode  UnitPrice
# 0    21137F       7.62 307197
#   StockCode  UnitPrice
# 0    23310X       0.42 307287
#   StockCode  UnitPrice
# 0    21294T       1.25 308097
#   StockCode  UnitPrice
# 0    23243L       4.95 309087
#   StockCode  UnitPrice
# 0    21876I       3.36 312687
#   StockCode  UnitPrice
# 0    23077P       1.25 312777
#   StockCode  UnitPrice
# 0    22197J       0.85 313587
#   StockCode  UnitPrice
# 0    22867O        2.1 313677
#   StockCode  UnitPrice
# 0    22910D       5.91 314487
#   StockCode  UnitPrice
# 0    23293D       0.83 314577
#   StockCode  UnitPrice
# 0    22153K       0.42 315477
#   StockCode  UnitPrice
# 0    21294T       1.25 316377
#   StockCode  UnitPrice
# 0    84836J       1.25 317187
#   StockCode  UnitPrice
# 0    22026G       0.42 318087
#   StockCode  UnitPrice
# 0    84212C       0.65 319077
#   StockCode  UnitPrice
# 0    84991R       0.55 319977
#   StockCode  UnitPrice
# 0   85099BJ       1.65 320877
#   StockCode  UnitPrice
# 0   17084RT       0.21 322677
#   StockCode  UnitPrice
# 0    21928E       1.65 322767
#   StockCode  UnitPrice
# 0    22791E       1.25 323577
#   StockCode  UnitPrice
# 0    23376B       0.39 323766
#   StockCode  UnitPrice
# 0    23202Z        0.0 325377
#   StockCode  UnitPrice
# 0   51014CF       0.85 325467
#   StockCode  UnitPrice
# 0    21166I       1.95 326277
#   StockCode  UnitPrice
# 0   15056ND       4.25 327267
#   StockCode  UnitPrice
# 0    22492E       1.66 327366
#   StockCode  UnitPrice
# 0   75049LA       2.46 328167
#   StockCode  UnitPrice
# 0    23498F       1.45 328176
#   StockCode  UnitPrice
# 0    23555W       12.5 330066
#   StockCode  UnitPrice
# 0    21166I       1.95 331857
#   StockCode  UnitPrice
# 0    22294U       1.25 331956
#   StockCode  UnitPrice
# 0   16161PA       0.42 332757
#   StockCode  UnitPrice
# 0    84077K       0.29 332766
#   StockCode  UnitPrice
# 0   85099BJ       1.65 333567
#   StockCode  UnitPrice
# 0   85132CX       9.95 333657
#   StockCode  UnitPrice
# 0    84945I       0.85 333666
#   StockCode  UnitPrice
# 0    22086O       5.91 333756
#   StockCode  UnitPrice
# 0    21790Y       0.85 334656
#   StockCode  UnitPrice
# 0    82581P       1.28 335457
#   StockCode  UnitPrice
# 0    22610S       0.21 335466
#   StockCode  UnitPrice
# 0   82001SP       3.75 335556
#   StockCode  UnitPrice
# 0    21212D       0.55 336357
#   StockCode  UnitPrice
# 0    21912V       3.75 336366
#   StockCode  UnitPrice
# 0    21181K        2.1 337167
#   StockCode  UnitPrice
# 0    22197J       0.85 338256
#   StockCode  UnitPrice
# 0    84754D       1.25 339057
#   StockCode  UnitPrice
# 0    20668K        0.1 339156
#   StockCode  UnitPrice
# 0    22178V       2.51 339957
#   StockCode  UnitPrice
# 0    20992N       0.85 340857
#   StockCode  UnitPrice
# 0    72818G       0.85 340956
#   StockCode  UnitPrice
# 0    21824R       1.45 341856
#   StockCode  UnitPrice
# 0    22704P       0.42 342747
#   StockCode  UnitPrice
# 0    21811V       2.51 342756
#   StockCode  UnitPrice
# 0    23545U       0.42 342846
#   StockCode  UnitPrice
# 0    20668K        0.1 343746
#   StockCode  UnitPrice
# 0    22988D       2.51 344457
#   StockCode  UnitPrice
# 0    23499W       0.42 344556
#   StockCode  UnitPrice
# 0    84978X       1.25 345357
#   StockCode  UnitPrice
# 0    23273Z       1.65 345456
#   StockCode  UnitPrice
# 0    22666I       2.95 345546
#   StockCode  UnitPrice
# 0    22383K       1.65 347157
#   StockCode  UnitPrice
# 0    22961C       1.45 347247
#   StockCode  UnitPrice
# 0    84879M       1.69 349947
#   StockCode  UnitPrice
# 0    21879Z       0.19 351837
#   StockCode  UnitPrice
# 0    21495P       0.42 351846
#   StockCode  UnitPrice
# 0    22900U       2.95 352647
#   StockCode  UnitPrice
# 0    22197J       0.85 352836
#   StockCode  UnitPrice
# 0    22492E       1.66 353547
#   StockCode  UnitPrice
# 0    22952P       0.55 354447
#   StockCode  UnitPrice
# 0   15056ND       4.25 354546
#   StockCode  UnitPrice
# 0    21621T      16.98 355347
#   StockCode  UnitPrice
# 0   85099BJ       1.65 355536
#   StockCode  UnitPrice
# 0    23198Y       1.45 356337
#   StockCode  UnitPrice
# 0    22383K       1.65 356346
#   StockCode  UnitPrice
# 0    84077K       0.29 357237
#   StockCode  UnitPrice
# 0    22097D       1.25 357246
#   StockCode  UnitPrice
# 0    22419N       0.85 358047
#   StockCode  UnitPrice
# 0    71477B       3.25 358146
#   StockCode  UnitPrice
# 0    21931F       4.21 358236
#   StockCode  UnitPrice
# 0    22197J       0.85 359136
#   StockCode  UnitPrice
# 0    22086O       5.91 360936
#   StockCode  UnitPrice
# 0    22489J       0.42 361926
#   StockCode  UnitPrice
# 0    16016H       0.85 362727
#   StockCode  UnitPrice
# 0    22469S       1.65 362736
#   StockCode  UnitPrice
# 0    84826T       0.21 363636
#   StockCode  UnitPrice
# 0    22151L       0.42 363726
#   StockCode  UnitPrice
# 0    22086O       5.91 364437
#   StockCode  UnitPrice
# 0    22114V       3.95 364527
#   StockCode  UnitPrice
# 0    21641J       1.66 365337
#   StockCode  UnitPrice
# 0    23480U       3.75 365427
#   StockCode  UnitPrice
# 0    84755J       1.27 365436
#   StockCode  UnitPrice
# 0    84946F       2.51 366237
#   StockCode  UnitPrice
# 0    23493H       1.95 366426
#   StockCode  UnitPrice
# 0    23210F       1.25 367227
#   StockCode  UnitPrice
# 0    23344R       2.08 367236
#   StockCode  UnitPrice
# 0    22030B       0.42 367326
#   StockCode  UnitPrice
# 0    15030G       0.29 368136
#   StockCode  UnitPrice
# 0    22151L       0.42 369126
#   StockCode  UnitPrice
# 0    82580N       0.55 369927
#   StockCode  UnitPrice
# 0    84949O       1.65 370026
#   StockCode  UnitPrice
# 0    22492E       1.66 370827
#   StockCode  UnitPrice
# 0    84568Z       0.21 370926
#   StockCode  UnitPrice
# 0    22693N       1.25 371916
#   StockCode  UnitPrice
# 0    22197J       0.85 372726
#   StockCode  UnitPrice
# 0    84879M       1.69 373527
#   StockCode  UnitPrice
# 0    23157X       2.08 374427
#   StockCode  UnitPrice
# 0    22154A       0.42 374517
#   StockCode  UnitPrice
# 0    22740K       1.66 375426
#   StockCode  UnitPrice
# 0    84077K       0.29 375516
#   StockCode  UnitPrice
# 0    23209X       1.65 376227
#   StockCode  UnitPrice
# 0    23300F       1.65 376317
#   StockCode  UnitPrice
# 0   84926AC       1.25 377127
#   StockCode  UnitPrice
# 0    23374A       0.82 377217
#   StockCode  UnitPrice
# 0    23006Q       0.83 378027
#   StockCode  UnitPrice
# 0    22178V       2.51 378216
#   StockCode  UnitPrice
# 0    17003M       0.42 380016
#   StockCode  UnitPrice
# 0    22711H       0.42 380817
#   StockCode  UnitPrice
# 0    84978X       1.25 380916
#   StockCode  UnitPrice
# 0   46000SJ       1.45 382716
#   StockCode  UnitPrice
# 0    22047L       0.42 383706
#   StockCode  UnitPrice
# 0    21790Y       0.85 385416
#   StockCode  UnitPrice
# 0    22030B       0.42 387216
#   StockCode  UnitPrice
# 0   17084NU       0.43 388116
#   StockCode  UnitPrice
# 0    23199M       1.95 392706
#   StockCode  UnitPrice
# 0    15034D       0.85 392796
#   StockCode  UnitPrice
# 0   85123AY       2.55 394506
#   StockCode  UnitPrice
# 0   79063DS       0.19 396306
#   StockCode  UnitPrice
# 0    23439A        2.1 397206
#   StockCode  UnitPrice
# 0    23194R       2.25 397296
#   StockCode  UnitPrice
# 0   17012CF       2.51 398106
#   StockCode  UnitPrice
# 0    85152E        2.1 398196
#   StockCode  UnitPrice
# 0    23431D       0.72 399096
#   StockCode  UnitPrice
# 0    22197J       0.85 399996
#   StockCode  UnitPrice
# 0    21985C       0.29 401796
#   StockCode  UnitPrice
# 0   84970SL       2.13 401886
#   StockCode  UnitPrice
# 0    82600H       4.21 402786
#   StockCode  UnitPrice
# 0    71459J       0.85 403596
#   StockCode  UnitPrice
# 0    22419N       0.85 403686
#   StockCode  UnitPrice
# 0    20733F       0.85 405396
#   StockCode  UnitPrice
# 0    22534C       0.85 406386
#   StockCode  UnitPrice
# 0    84879M       1.69 407286
#   StockCode  UnitPrice
# 0    21731V       3.36 408186
#   StockCode  UnitPrice
# 0    22492E       1.66 411786
#   StockCode  UnitPrice
# 0    20725N       1.65 413676
#   StockCode  UnitPrice
# 0    37342P       0.85 415386
#   StockCode  UnitPrice
# 0    21112W       1.25 415476
#   StockCode  UnitPrice
# 0    23068E       2.08 416286
#   StockCode  UnitPrice
# 0    23077P       1.25 418086
#   StockCode  UnitPrice
# 0    22189I       3.95 419076
#   StockCode  UnitPrice
# 0    22385P       5.06 420876
#   StockCode  UnitPrice
# 0    21877C       1.25 422676
#   StockCode  UnitPrice
# 0    23084M       2.08 425466
#   StockCode  UnitPrice
# 0    22741O       1.66 426366
#   StockCode  UnitPrice
# 0    23498F       1.45 427176
#   StockCode  UnitPrice
# 0    22043M       0.42 428076
#   StockCode  UnitPrice
# 0    21623S       9.95 429966
#   StockCode  UnitPrice
# 0    22740K       1.66 431856
#   StockCode  UnitPrice
# 0    23326S       0.55 433566
#   StockCode  UnitPrice
# 0    22561Z       3.36 434466
#   StockCode  UnitPrice
# 0   85123AY       2.55 438156
#   StockCode  UnitPrice
# 0    22708V       0.42 440055
#   StockCode  UnitPrice
# 0   85099BJ       1.65 440856
#   StockCode  UnitPrice
# 0    22151L       0.42 441846
#   StockCode  UnitPrice
# 0    22706R       0.42 441855
#   StockCode  UnitPrice
# 0    21980L       0.29 441945
#   StockCode  UnitPrice
# 0    20668K        0.1 442755
#   StockCode  UnitPrice
# 0   85123AY       2.55 443646
#   StockCode  UnitPrice
# 0   85025CA       1.65 443745
#   StockCode  UnitPrice
# 0    21930O       1.95 444456
#   StockCode  UnitPrice
# 0    21213V       0.55 444546
#   StockCode  UnitPrice
# 0    37370Z       1.06 444555
#   StockCode  UnitPrice
# 0    47422C       0.42 444645
#   StockCode  UnitPrice
# 0    22469S       1.65 445356
#   StockCode  UnitPrice
# 0    21535E        2.1 445446
#   StockCode  UnitPrice
# 0    22045U       0.42 446445
#   StockCode  UnitPrice
# 0    23170S       1.65 448056
#   StockCode  UnitPrice
# 0    22303W       2.55 448245
#   StockCode  UnitPrice
# 0   85123AY       2.55 451746
#   StockCode  UnitPrice
# 0    21993R       2.51 451836
#   StockCode  UnitPrice
# 0    21868Y       3.36 452646
#   StockCode  UnitPrice
# 0    23000P       0.42 452745
#   StockCode  UnitPrice
# 0    21181K        2.1 455535
#   StockCode  UnitPrice
# 0    23215I       2.08 456246
#   StockCode  UnitPrice
# 0    20724F       1.66 456336
#   StockCode  UnitPrice
# 0    22560W       1.25 456345
#   StockCode  UnitPrice
# 0    22972W       3.36 456435
#   StockCode  UnitPrice
# 0   16168MP       0.42 457335
#   StockCode  UnitPrice
# 0    22383K       1.65 458046
#   StockCode  UnitPrice
# 0    23084M       2.08 458136
#   StockCode  UnitPrice
# 0    21195Z       4.21 458145
#   StockCode  UnitPrice
# 0    84879M       1.69 459036
#   StockCode  UnitPrice
# 0    21232B       1.25 459135
#   StockCode  UnitPrice
# 0    21809L       2.51 459936
#   StockCode  UnitPrice
# 0    22423U      12.75 460935
#   StockCode  UnitPrice
# 0    23158A       2.08 461736
#   StockCode  UnitPrice
# 0    22491V       0.85 462825
#   StockCode  UnitPrice
# 0    22600F       0.85 463536
#   StockCode  UnitPrice
# 0    84950I       0.65 463635
#   StockCode  UnitPrice
# 0   15056ND       4.25 463725
#   StockCode  UnitPrice
# 0    22771L       1.25 465426
#   StockCode  UnitPrice
# 0   16169EL       0.42 467136
#   StockCode  UnitPrice
# 0    22818I       0.42 468126
#   StockCode  UnitPrice
# 0    21080R       0.64 468135
#   StockCode  UnitPrice
# 0   85099FC       1.95 469125
#   StockCode  UnitPrice
# 0    84945I       0.85 469926
#   StockCode  UnitPrice
# 0    22699D       2.95 472815
#   StockCode  UnitPrice
# 0    22809N       2.95 473526
#   StockCode  UnitPrice
# 0    84946F       2.51 473625
#   StockCode  UnitPrice
# 0    20713F       1.95 474615
#   StockCode  UnitPrice
# 0    22544C       0.85 476316
#   StockCode  UnitPrice
# 0    21879Z       0.19 476415
#   StockCode  UnitPrice
# 0    22952P       0.55 477216
#   StockCode  UnitPrice
# 0    22985B       0.42 478026
#   StockCode  UnitPrice
# 0    22544C       0.85 480816
#   StockCode  UnitPrice
# 0    22491V       0.85 480915
#   StockCode  UnitPrice
# 0    22616B       0.29 482805
#   StockCode  UnitPrice
# 0    21390P       1.25 484515
#   StockCode  UnitPrice
# 0   85123AY       2.55 485415
#   StockCode  UnitPrice
# 0    84077K       0.29 486315
#   StockCode  UnitPrice
# 0    22959R       0.42 487215
#   StockCode  UnitPrice
# 0    22435K       1.25 488205
#   StockCode  UnitPrice
# 0    21498M       0.42 489105
#   StockCode  UnitPrice
# 0    23084M       2.08 491805
#   StockCode  UnitPrice
# 0    22986P       0.42 491895
#   StockCode  UnitPrice
# 0    22652D       1.65 493605
#   StockCode  UnitPrice
# 0    22086O       5.91 497205
#   StockCode  UnitPrice
# 0    22610S       0.21 500895
#   StockCode  UnitPrice
# 0    23843K       2.08 501885
#   StockCode  UnitPrice
# 0    84755J       1.27 505395
#   StockCode  UnitPrice
# 0    22704P       0.42 505485
#   StockCode  UnitPrice
# 0    22336O       1.28 506295
#   StockCode  UnitPrice
# 0    23546H       0.42 507195
#   StockCode  UnitPrice
# 0    23280V       0.83 508185
#   StockCode  UnitPrice
# 0    20974J       1.28 510885
#   StockCode  UnitPrice
# 0    21829T       0.43 511785
#   StockCode  UnitPrice
# 0    84879M       1.69 511875
#   StockCode  UnitPrice
# 0    23207R       1.65 512775
#   StockCode  UnitPrice
# 0    21929W       4.21 513675
#   StockCode  UnitPrice
# 0    35957E       0.42 515385
#   StockCode  UnitPrice
# 0    22197J       0.85 516285
#   StockCode  UnitPrice
# 0   85099BJ       1.65 518085
#   StockCode  UnitPrice
# 0    22197J       0.85 520875
#   StockCode  UnitPrice
# 0    62018W       1.25 521775
#   StockCode  UnitPrice
# 0    16219C       0.21 521865
#   StockCode  UnitPrice
# 0    22945X       0.85 522765
#   StockCode  UnitPrice
# 0    21977R       0.42 523575
#   StockCode  UnitPrice
# 0    23327C       0.63 523665
#   StockCode  UnitPrice
# 0    23353X       0.83 524475
#   StockCode  UnitPrice
# 0    22355U       1.66 525375
#   StockCode  UnitPrice
# 0    22598V       1.66 526275
#   StockCode  UnitPrice
# 0    22816Q       0.42 528075
#   StockCode  UnitPrice
# 0    22151L       0.42 528165
#   StockCode  UnitPrice
# 0    21982Y       0.85 529065
#   StockCode  UnitPrice
# 0    22771L       1.25 530865
#   StockCode  UnitPrice
# 0    47566Y       4.65 531765
#   StockCode  UnitPrice
# 0    21239K       0.85 531855
#   StockCode  UnitPrice
# 0    21094A       0.64 532755
#   StockCode  UnitPrice
# 0    23207R       1.65 536265
#   StockCode  UnitPrice
# 0    22197J       0.85 536355
#   StockCode  UnitPrice
# 0    21523L       6.75 538065
#   StockCode  UnitPrice
# 0    72741B       2.82 539055
#   StockCode  UnitPrice
# 0   75049LA       2.46 540855
#   StockCode  UnitPrice
# 0   17091JD       2.51 541755
#   StockCode  UnitPrice
# 0    22492E       1.66 541845
#   StockCode  UnitPrice
# 0   85099BJ       1.65 542655
#   StockCode  UnitPrice
# 0    21539P       4.95 542745
#   StockCode  UnitPrice
# 0    84568Z       0.21 544455
#   StockCode  UnitPrice
# 0   85230BW       0.29 546255
#   StockCode  UnitPrice
# 0   15056ND       4.25 547155
#   StockCode  UnitPrice
# 0    84077K       0.29 548055
#   StockCode  UnitPrice
# 0    22966E       1.25 550845
#   StockCode  UnitPrice
# 0    21917S       0.42 552645
#   StockCode  UnitPrice
# 0    23313G       4.95 553545
#   StockCode  UnitPrice
# 0    84879M       1.69 554445
#   StockCode  UnitPrice
# 0    23077P       1.25 555435
#   StockCode  UnitPrice
# 0    21810L       2.51 556245
#   StockCode  UnitPrice
# 0    21213V       0.55 556335
#   StockCode  UnitPrice
# 0    22625P        8.5 557235
#   StockCode  UnitPrice
# 0    84879M       1.69 560835
#   StockCode  UnitPrice
# 0    23480U       3.75 561735
#   StockCode  UnitPrice
# 0    21181K        2.1 562635
#   StockCode  UnitPrice
# 0    23172Q       1.65 563625
#   StockCode  UnitPrice
# 0    22154A       0.42 565335
#   StockCode  UnitPrice
# 0    23084M       2.08 567225
#   StockCode  UnitPrice
# 0    21213V       0.55 569925
#   StockCode  UnitPrice
# 0    23084M       2.08 570825
#   StockCode  UnitPrice
# 0    22616B       0.29 574425
#   StockCode  UnitPrice
# 0    22296X       1.65 575415
#   StockCode  UnitPrice
# 0    22910D       5.91 576225
#   StockCode  UnitPrice
# 0    22079R       1.65 579015
